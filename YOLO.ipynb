# %%
import torch
import cv2
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt


from ultralytics import YOLO

def load_model():
    model = YOLO('yolov5s.pt')
    return model

def detect_humans(model, image_path):
    # Read the image
    img = cv2.imread(image_path)
    if img is None:
        print(f"Error: Unable to read image at {image_path}")
        return
    results = model(img)

    # Process results
    for result in results:
        boxes = result.boxes.cpu().numpy()
        for box in boxes:
            if box.cls == 0:
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                conf = box.conf[0]
                cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
                cv2.putText(img, f'Human: {conf:.2f}', (x1, y1 - 10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # Display the result using matplotlib
    plt.figure(figsize=(12, 8))
    plt.imshow(img_rgb)
    plt.axis('off')
    plt.title('Human Detection Result')
    plt.show()

def main():
    model = load_model()

    image_path = input("Enter the path to an image: ")
    detect_humans(model, image_path)

if __name__ == "__main__":
    main()
# Out:
# PRO TIP 💡 Replace 'model=yolov5s.pt' with new 'model=yolov5su.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# Enter the path to an image: /content/images/game-of-thrones-a-song-of-ice-and-fire-archery-tv-series-jon-snow-robb-stark-brandon-stark-winterfel-entertainment-tv-series-hd-art-wallpaper-preview.jpg
#
# 0: 448x640 7 persons, 422.7ms
# Speed: 5.7ms preprocess, 422.7ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)

# %%
import torch
import cv2
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt


from ultralytics import YOLO

def load_model():
    model = YOLO('yolov5s.pt')
    return model

def detect_humans(model, image_path):
    # Read the image
    img = cv2.imread(image_path)
    if img is None:
        print(f"Error: Unable to read image at {image_path}")
        return
    results = model(img)

    # Process results
    for result in results:
        boxes = result.boxes.cpu().numpy()
        for box in boxes:
            if box.cls == 0:
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                conf = box.conf[0]
                cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
                cv2.putText(img, f'Human: {conf:.2f}', (x1, y1 - 10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # Display the result using matplotlib
    plt.figure(figsize=(12, 8))
    plt.imshow(img_rgb)
    plt.axis('off')
    plt.title('Human Detection Result')
    plt.show()

def main():
    model = load_model()

    image_path = input("Enter the path to an image: ")
    detect_humans(model, image_path)

if __name__ == "__main__":
    main()
# Out:
# PRO TIP 💡 Replace 'model=yolov5s.pt' with new 'model=yolov5su.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# Enter the path to an image: /content/images/0_0tpsu5ZoWZ9-Wg6N.jpg
#
# 0: 384x640 10 persons, 365.7ms
# Speed: 5.6ms preprocess, 365.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
